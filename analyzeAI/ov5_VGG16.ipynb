# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
# from google.colab import drive

# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set the path to the image dataset folder
dataset_path = 'C:/Users/nisri/Downloads/capstone/sigma-onion-sensor/analyzeAI/Training_ov5'

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the class labels
class_labels = ['Moler', 'Purple blotch', 'Healthy']
num_classes = len(class_labels)

# Image Data Generators with augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2
)

# No augmentation for the validation data, just rescaling
validation_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# Generate training and validation batches from directories
train_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),  # Adjusted for VGG16
    batch_size=32,
    class_mode='sparse',
    subset='training'
)

validation_generator = validation_datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),  # Adjusted for VGG16
    batch_size=32,
    class_mode='sparse',
    subset='validation'
)

# Print class indices to ensure consistent label mapping
print("Class indices for training data:", train_generator.class_indices)
print("Class indices for validation data:", validation_generator.class_indices)
# Out:
# Found 360 images belonging to 3 classes.
# Found 90 images belonging to 3 classes.
# Class indices for training data: {'healthy': 0, 'moler': 1, 'purple blotch': 2}
# Class indices for validation data: {'healthy': 0, 'moler': 1, 'purple blotch': 2}

# %%
# Load VGG16 pre-trained model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = False

# Adding custom layers on top of VGG16
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(num_classes, activation='softmax')(x)

# This is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(lr=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 14978883 (57.14 MB)
# Trainable params: 264195 (1.01 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=50,  # You can adjust epochs based on your observation
    validation_data=validation_generator
)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 319s 26s/step - loss: 1.0175 - accuracy: 0.5167 - val_loss: 1.0115 - val_accuracy: 0.5667
# Epoch 2/50
# 12/12 [==============================] - 290s 24s/step - loss: 0.7378 - accuracy: 0.7056 - val_loss: 0.9557 - val_accuracy: 0.5556
# Epoch 3/50
# 12/12 [==============================] - 313s 27s/step - loss: 0.6322 - accuracy: 0.7583 - val_loss: 0.8815 - val_accuracy: 0.5444
# Epoch 4/50
# 12/12 [==============================] - 291s 25s/step - loss: 0.5216 - accuracy: 0.8222 - val_loss: 0.7964 - val_accuracy: 0.6444
# Epoch 5/50
# 12/12 [==============================] - 312s 26s/step - loss: 0.4402 - accuracy: 0.8417 - val_loss: 0.7600 - val_accuracy: 0.6111
# Epoch 6/50
# 12/12 [==============================] - 292s 25s/step - loss: 0.3986 - accuracy: 0.8611 - val_loss: 0.6508 - val_accuracy: 0.7111
# Epoch 7/50
# 12/12 [==============================] - 285s 25s/step - loss: 0.3929 - accuracy: 0.8472 - val_loss: 0.5785 - val_accuracy: 0.7444
# Epoch 8/50
# 12/12 [==============================] - 285s 24s/step - loss: 0.3415 - accuracy: 0.8833 - val_loss: 0.5375 - val_accuracy: 0.7667
# Epoch 9/50
# 12/12 [==============================] - 312s 28s/step - loss: 0.2902 - accuracy: 0.9083 - val_loss: 0.4989 - val_accuracy: 0.8000
# Epoch 10/50
# 12/12 [==============================] - 285s 24s/step - loss: 0.2969 - accuracy: 0.8944 - val_loss: 0.4774 - val_accuracy: 0.7778
# Epoch 11/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.2717 - accuracy: 0.9194 - val_loss: 0.4366 - val_accuracy: 0.8444
# Epoch 12/50
# 12/12 [==============================] - 284s 25s/step - loss: 0.2407 - accuracy: 0.9278 - val_loss: 0.4069 - val_accuracy: 0.8778
# Epoch 13/50
# 12/12 [==============================] - 312s 28s/step - loss: 0.2392 - accuracy: 0.9361 - val_loss: 0.4054 - val_accuracy: 0.8333
# Epoch 14/50
# 12/12 [==============================] - 285s 24s/step - loss: 0.2377 - accuracy: 0.9083 - val_loss: 0.3767 - val_accuracy: 0.8778
# Epoch 15/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.2318 - accuracy: 0.9139 - val_loss: 0.3798 - val_accuracy: 0.8444
# Epoch 16/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.2056 - accuracy: 0.9361 - val_loss: 0.3508 - val_accuracy: 0.8667
# Epoch 17/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.1840 - accuracy: 0.9333 - val_loss: 0.3277 - val_accuracy: 0.9111
# Epoch 18/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.1909 - accuracy: 0.9444 - val_loss: 0.3293 - val_accuracy: 0.8667
# Epoch 19/50
# 12/12 [==============================] - 313s 28s/step - loss: 0.1748 - accuracy: 0.9556 - val_loss: 0.3393 - val_accuracy: 0.9000
# Epoch 20/50
# 12/12 [==============================] - 287s 24s/step - loss: 0.1773 - accuracy: 0.9444 - val_loss: 0.2844 - val_accuracy: 0.9111
# Epoch 21/50
# 12/12 [==============================] - 314s 26s/step - loss: 0.1643 - accuracy: 0.9444 - val_loss: 0.2695 - val_accuracy: 0.9222
# Epoch 22/50
# 12/12 [==============================] - 313s 26s/step - loss: 0.1775 - accuracy: 0.9472 - val_loss: 0.2975 - val_accuracy: 0.8667
# Epoch 23/50
# 12/12 [==============================] - 310s 26s/step - loss: 0.1711 - accuracy: 0.9444 - val_loss: 0.2663 - val_accuracy: 0.9000
# Epoch 24/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.1576 - accuracy: 0.9500 - val_loss: 0.2702 - val_accuracy: 0.9000
# Epoch 25/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.1411 - accuracy: 0.9611 - val_loss: 0.2531 - val_accuracy: 0.9111
# Epoch 26/50
# 12/12 [==============================] - 313s 26s/step - loss: 0.1146 - accuracy: 0.9667 - val_loss: 0.2309 - val_accuracy: 0.9222
# Epoch 27/50
# 12/12 [==============================] - 287s 24s/step - loss: 0.1408 - accuracy: 0.9611 - val_loss: 0.2212 - val_accuracy: 0.9444
# Epoch 28/50
# 12/12 [==============================] - 312s 26s/step - loss: 0.1240 - accuracy: 0.9639 - val_loss: 0.2210 - val_accuracy: 0.9333
# Epoch 29/50
# 12/12 [==============================] - 287s 24s/step - loss: 0.1153 - accuracy: 0.9722 - val_loss: 0.2128 - val_accuracy: 0.9222
# Epoch 30/50
# 12/12 [==============================] - 285s 24s/step - loss: 0.1032 - accuracy: 0.9722 - val_loss: 0.2117 - val_accuracy: 0.9222
# Epoch 31/50
# 12/12 [==============================] - 287s 24s/step - loss: 0.1483 - accuracy: 0.9556 - val_loss: 0.2079 - val_accuracy: 0.9333
# Epoch 32/50
# 12/12 [==============================] - 313s 26s/step - loss: 0.1179 - accuracy: 0.9667 - val_loss: 0.2202 - val_accuracy: 0.9111
# Epoch 33/50
# 12/12 [==============================] - 312s 28s/step - loss: 0.1010 - accuracy: 0.9806 - val_loss: 0.2194 - val_accuracy: 0.9222
# Epoch 34/50
# 12/12 [==============================] - 287s 24s/step - loss: 0.1088 - accuracy: 0.9806 - val_loss: 0.2121 - val_accuracy: 0.9333
# Epoch 35/50
# 12/12 [==============================] - 313s 26s/step - loss: 0.1058 - accuracy: 0.9722 - val_loss: 0.1847 - val_accuracy: 0.9444
# Epoch 36/50
# 12/12 [==============================] - 310s 26s/step - loss: 0.1021 - accuracy: 0.9694 - val_loss: 0.1937 - val_accuracy: 0.9222
# Epoch 37/50
# 12/12 [==============================] - 285s 24s/step - loss: 0.0960 - accuracy: 0.9750 - val_loss: 0.2441 - val_accuracy: 0.8889
# Epoch 38/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.0853 - accuracy: 0.9750 - val_loss: 0.1697 - val_accuracy: 0.9556
# Epoch 39/50
# 12/12 [==============================] - 312s 27s/step - loss: 0.0879 - accuracy: 0.9778 - val_loss: 0.1721 - val_accuracy: 0.9333
# Epoch 40/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.0965 - accuracy: 0.9694 - val_loss: 0.2190 - val_accuracy: 0.9111
# Epoch 41/50
# 12/12 [==============================] - 287s 24s/step - loss: 0.0922 - accuracy: 0.9750 - val_loss: 0.1888 - val_accuracy: 0.9222
# Epoch 42/50
# 12/12 [==============================] - 287s 24s/step - loss: 0.0903 - accuracy: 0.9778 - val_loss: 0.1658 - val_accuracy: 0.9556
# Epoch 43/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.0739 - accuracy: 0.9917 - val_loss: 0.1662 - val_accuracy: 0.9333
# Epoch 44/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.0777 - accuracy: 0.9833 - val_loss: 0.1501 - val_accuracy: 0.9556
# Epoch 45/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.0776 - accuracy: 0.9806 - val_loss: 0.1616 - val_accuracy: 0.9444
# Epoch 46/50
# 12/12 [==============================] - 313s 26s/step - loss: 0.0786 - accuracy: 0.9889 - val_loss: 0.2298 - val_accuracy: 0.9111
# Epoch 47/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.0621 - accuracy: 0.9833 - val_loss: 0.1573 - val_accuracy: 0.9667
# Epoch 48/50
# 12/12 [==============================] - 285s 25s/step - loss: 0.0696 - accuracy: 0.9861 - val_loss: 0.1639 - val_accuracy: 0.9333
# Epoch 49/50
# 12/12 [==============================] - 286s 24s/step - loss: 0.0653 - accuracy: 0.9806 - val_loss: 0.1448 - val_accuracy: 0.9667
# Epoch 50/50
# 12/12 [==============================] - 313s 27s/step - loss: 0.0572 - accuracy: 0.9944 - val_loss: 0.1456 - val_accuracy: 0.9444

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# Evaluate the model on the validation set
validation_loss, validation_accuracy = model.evaluate(validation_generator)

# Reset the validation generator
validation_generator.reset()

# Fetch and predict all images in the validation set
predictions = []
true_labels = []
for _ in range(len(validation_generator)):
    x_val, y_val = next(validation_generator)
    preds = model.predict(x_val)
    predictions.extend(np.argmax(preds, axis=1))
    true_labels.extend(y_val)

# Generate the confusion matrix
cm = confusion_matrix(true_labels, predictions)
class_labels = list(validation_generator.class_indices.keys())

# Plot the confusion matrix
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Print the classification report
print(classification_report(true_labels, predictions, target_names=class_labels))

print(f"Validation Loss: {validation_loss:.4f}")
print(f"Validation Accuracy: {validation_accuracy * 100:.2f}%")
# Out:
# 3/3 [==============================] - 58s 18s/step - loss: 0.1456 - accuracy: 0.9444
# 1/1 [==============================] - 20s 20s/step
# 1/1 [==============================] - 21s 21s/step
# 1/1 [==============================] - 17s 17s/step
#                precision    recall  f1-score   support
#
#       healthy       0.93      0.93      0.93        30
#         moler       0.94      1.00      0.97        30
# purple blotch       0.96      0.90      0.93        30
#
#      accuracy                           0.94        90
#     macro avg       0.95      0.94      0.94        90
#  weighted avg       0.95      0.94      0.94        90
#
# Validation Loss: 0.1456
# Validation Accuracy: 94.44%

# %%
# Create a test data generator, which only rescales the images
test_datagen = ImageDataGenerator(rescale=1./255)

# Generate batches of test images
test_generator = test_datagen.flow_from_directory(
    'C:/Users/nisri/Downloads/capstone/sigma-onion-sensor/analyzeAI/Testing_ov5',
    target_size=(224, 224),
    batch_size=32,  # Adjust the batch size according to your needs
    class_mode='sparse',  # Ensure the class mode matches the one used during training
    shuffle=False  # Do not shuffle the data for testing; it's important for matching outputs with labels
)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_generator)

# Predict all images in the test set for detailed classification report
test_generator.reset()  # Resetting generator to ensure correct label matching
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get the true labels from the generator
true_classes = test_generator.classes

# Print the classification report including F1 score, precision, and recall
print(classification_report(true_classes, predicted_classes, target_names=test_generator.class_indices.keys()))

# Print accuracy and loss
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Found 60 images belonging to 3 classes.
# 2/2 [==============================] - 39s 17s/step - loss: 0.4704 - accuracy: 0.7833
# 2/2 [==============================] - 37s 17s/step
#                precision    recall  f1-score   support
#
#       healthy       0.77      0.50      0.61        20
#         moler       1.00      1.00      1.00        20
# purple blotch       0.63      0.85      0.72        20
#
#      accuracy                           0.78        60
#     macro avg       0.80      0.78      0.78        60
#  weighted avg       0.80      0.78      0.78        60
#
# Test Loss: 0.4704
# Test Accuracy: 78.33%

# %%
# Save the model
model.save('/content/drive/MyDrive/fix/ov5_VGG16.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
